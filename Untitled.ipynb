# %%
import numpy as np

# %%
data=np.load('vfx_seg.npz')

# %%
tx=data['tx']

# %%
print tx.shape
# Out:
# (323, 1080, 1920, 3)

# %%
from scipy import ndimage

# %%
affine=np.array([1,1079/511,1919/511.0,1])

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.imshow(tx[0])

# %%
ttx=ndimage.affine_transform(tx[0:5],affine,output_shape=(5,512,512,3))

# %%
plt.imshow(ttx[0])
